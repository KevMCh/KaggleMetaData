# %%
import pandas as pd

# %% [markdown]
# ## Tags

# %%
tags = pd.read_csv("Tags.csv", engine='python')

tagsAndParents = tags[["Name", "Id"]]
tagsAndParents = tagsAndParents.rename(columns={"Id": "ParentId", "Name": "ParentTagName"})

tagsAndParents = pd.merge(tags, tagsAndParents, left_on="ParentTagId", right_on="ParentId")
tagsAndParents = tagsAndParents.drop(['ParentTagId', 'ParentId'], axis=1)

tagsAndParents.head()
# Out:
#       Id                 Name                 Slug  \
# 0   1115             websites            web-sites
# 1   1220       search engines       search-engines
# 2  12117  mobile and wireless           mobile-web
# 3  16486  email and messaging  email-and-messaging
# 4  16489   online communities   online-communities
#
#                                             FullPath  \
# 0  subject > science and technology > internet > ...
# 1  subject > science and technology > internet > ...
# 2  subject > science and technology > internet > ...
# 3  subject > science and technology > internet > ...
# 4  subject > science and technology > internet > ...
#
#                                          Description  DatasetCount  \
# 0  Websites, like this one, are collections of co...           250
# 1                                                NaN            72
# 2                                                NaN           601
# 3                                                NaN          2129
# 4                                                NaN          6829
#
#    CompetitionCount  KernelCount ParentTagName
# 0                 0          209      internet
# 1                 0           72      internet
# 2                 4          149      internet
# 3                 1          129      internet
# 4                 3         1232      internet

# %% [markdown]
# ### Datasets

# %%
datasets = pd.read_csv("Datasets.csv", engine='python')
datasets.head()
# Out:
#    Id  CreatorUserId  OwnerUserId  OwnerOrganizationId  \
# 0  17            993          NaN                  3.0
# 1  19              1          NaN                  7.0
# 2  26         553913     553913.0                  NaN
# 3  28        1132983          NaN                223.0
# 4  53         627861          NaN                621.0
#
#    CurrentDatasetVersionId  CurrentDatasourceVersionId  ForumId  Type  \
# 0                 742210.0                    762847.0      989     2
# 1                    420.0                       420.0      997     2
# 2                 793501.0                    815299.0     1110     2
# 3                   3144.0                      3144.0     1116     2
# 4                    102.0                       102.0     1318     2
#
#           CreationDate LastActivityDate  TotalViews  TotalDownloads  \
# 0  01/07/2016 00:38:08       02/06/2018      556331           77206
# 1  01/12/2016 00:33:31       02/06/2018     1350146          344390
# 2  03/08/2016 22:41:02       02/05/2018       72166            9977
# 3  03/10/2016 04:37:43       02/06/2018      165689           18573
# 4  06/03/2016 00:27:28       02/04/2018       52292            5045
#
#    TotalVotes  TotalKernels
# 0         948           439
# 1        3170          5986
# 2         271           143
# 3         319           195
# 4          92           155

# %%
datasetTags = pd.read_csv("DatasetTags.csv", engine='python')
datasetTags.head()
# Out:
#      Id  DatasetId  TagId
# 0  1879       2234   1115
# 1  2182       2482   1115
# 2  2408       2700   1115
# 3  3756       8095   1115
# 4  5942      22268   1115

# %%
datasetsAndTags = pd.merge(datasetTags[["DatasetId", "TagId"]], tagsAndParents, left_on="TagId", right_on="Id")
datasetsAndTags = datasetsAndTags.drop(['Id', 'TagId'], axis=1)

datasetsAndTags = pd.merge(datasets, datasetsAndTags, left_on="Id", right_on="DatasetId")
datasetsAndTags = datasetsAndTags.drop(['DatasetId'], axis=1)

datasetsAndTags.head()
# Out:
#    Id  CreatorUserId  OwnerUserId  OwnerOrganizationId  \
# 0  17            993          NaN                  3.0
# 1  17            993          NaN                  3.0
# 2  17            993          NaN                  3.0
# 3  17            993          NaN                  3.0
# 4  19              1          NaN                  7.0
#
#    CurrentDatasetVersionId  CurrentDatasourceVersionId  ForumId  Type  \
# 0                 742210.0                    762847.0      989     2
# 1                 742210.0                    762847.0      989     2
# 2                 742210.0                    762847.0      989     2
# 3                 742210.0                    762847.0      989     2
# 4                    420.0                       420.0      997     2
#
#           CreationDate LastActivityDate  ...  TotalVotes  TotalKernels  \
# 0  01/07/2016 00:38:08       02/06/2018  ...         948           439
# 1  01/07/2016 00:38:08       02/06/2018  ...         948           439
# 2  01/07/2016 00:38:08       02/06/2018  ...         948           439
# 3  01/07/2016 00:38:08       02/06/2018  ...         948           439
# 4  01/12/2016 00:33:31       02/06/2018  ...        3170          5986
#
#           Name         Slug  \
# 0       health       health
# 1  linguistics  linguistics
# 2     internet     internet
# 3     aviation     aviation
# 4      biology      biology
#
#                                             FullPath  \
# 0              subject > health and fitness > health
# 1  subject > people and society > social science ...
# 2        subject > science and technology > internet
# 3  subject > science and technology > transportat...
# 4               subject > earth and nature > biology
#
#                                          Description DatasetCount  \
# 0  Consider the health tag your data science gym....         7337
# 1  The linguistics tag contains datasets and kern...          670
# 2  An interconnected network of tubes that connec...        10715
# 3  When you think of aviation, are you filled wit...          151
# 4  Explore datasets and kernels about gene expres...         5506
#
#   CompetitionCount  KernelCount           ParentTagName
# 0                5         7470      health and fitness
# 1                8          165          social science
# 2               18         2012  science and technology
# 3                0           42          transportation
# 4               10         4507        earth and nature
#
# [5 rows x 22 columns]

# %%
datasetTagAndValue = datasetsAndTags.groupby(['Name', 'ParentTagName'])['Name'].count()
datasetTagAndValue
# Out:
# Name                                  ParentTagName
# IPython                               packages             40
# PIL                                   packages              9
# RColorBrewer                          packages              1
# Two Sigma x Kaggle Finance Data Repo  initiatives         256
# accelerators                          computer science      9
#                                                          ...
# websites                              internet            231
# word2vec skip-gram                    architecture          1
# xgboost                               packages             61
# yolo                                  architecture          1
# yolov5                                architecture          2
# Name: Name, Length: 354, dtype: int64

# %%
datasetTagAndValue.to_csv('DatasetTagAndValueGeneral.csv')
